# %% [markdown]
# ## Exercise 2 - Step 1: Read CSV using pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

healthcare = pd.read_csv('healthcare_patients.csv')
print("\nHealthcare Data:")
print(healthcare)
# Out:
# Healthcare Data:
#    PatientID          Symptoms TestResult
# 0          1      Fever, Cough   Positive
# 1          2  Headache, Nausea   Negative
# 2          3    Cough, Fatigue   Positive
# 3          4        Chest Pain   Negative

# %% [markdown]
# ## Exercise 2 - Step 2: Define IF-THEN rules for symptoms to diagnosis mapping.

# %%
# Simple rule-based diagnosis
def diagnose(symptoms):
    if "Fever" in symptoms:
        return "Possible Infection"
    elif "Chest Pain" in symptoms:
        return "Seek Cardiac Evaluation"
    elif "Headache" in symptoms:
        return "Possible Migraine"
    elif "Cough" in symptoms:
        return "Respiratory Check Recommended"
    else:
        return "Monitor Symptoms"

# %% [markdown]
# ## Exercise 2 – Step 3: Apply rules and create a new column 'SuggestedDiagnosis'.

# %%
healthcare['SuggestedDiagnosis'] = healthcare['Symptoms'].apply(diagnose)
print("\nDiagnosis Suggestions:")
print(healthcare)
# Out:
# Diagnosis Suggestions:
#    PatientID          Symptoms TestResult             SuggestedDiagnosis
# 0          1      Fever, Cough   Positive             Possible Infection
# 1          2  Headache, Nausea   Negative              Possible Migraine
# 2          3    Cough, Fatigue   Positive  Respiratory Check Recommended
# 3          4        Chest Pain   Negative        Seek Cardiac Evaluation

# %%
# Optional visualization: count diagnoses
plt.figure(figsize=(8,5))
sns.countplot(y="SuggestedDiagnosis", data=healthcare, palette="crest")
plt.title("Suggested Diagnoses Frequency")
plt.xlabel("Count")
plt.ylabel("Diagnosis Type")
plt.show()
# Out:
# /var/folders/3k/p_t1dcts4h109f1kk34xfq6r0000gn/T/ipykernel_3832/576847192.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="SuggestedDiagnosis", data=healthcare, palette="crest")
